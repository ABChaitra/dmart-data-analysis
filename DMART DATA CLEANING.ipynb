# %%
import pandas as pd 
import numpy as np

# %%
dmart=pd.read_excel(r"C:\Users\Chaitra\Downloads\DMart Data Store.xlsx")

# %%
dmart
# Out:
#              Order ID Order Date     Customer Name         Country  \
# 0     BN-2011-7407039 2011-01-01        Ruby Patel          Sweden
# 1     AZ-2011-9050313 2011-01-03    Summer Hayward  United Kingdom
# 2     AZ-2011-6674300 2011-01-04  Devin Huddleston          France
# 3     BN-2011-2819714 2011-01-04       Mary Parker  United Kingdom
# 4     BN-2011-2819714 2011-01-04       Mary Parker  United Kingdom
# ...               ...        ...               ...             ...
# 8042   AZ-2014-766953 2014-12-31      Jose Gambino  United Kingdom
# 8043  BN-2014-4140795 2014-12-31   Daniel Hamilton     Netherlands
# 8044  BN-2014-4140795 2014-12-31   Daniel Hamilton     Netherlands
# 8045  BN-2014-4140795 2014-12-31   Daniel Hamilton     Netherlands
# 8046   AZ-2014-766953 2014-12-31      Jose Gambino  United Kingdom
#
#                      State        City   Region      Segment     Ship Mode  \
# 0                Stockholm   Stockholm    North  Home Office  Economy Plus
# ...

# %%
dmart.describe()
# Out:
#           Discount        Sales       Profit     Quantity
# count  8047.000000  8047.000000  8047.000000  8047.000000
# mean      0.110047   291.845657    35.198211     3.772089
# std       0.181773   485.212156   178.125844     2.203369
# min       0.000000     3.000000 -3060.000000     1.000000
# 25%       0.000000    48.000000     1.000000     2.000000
# 50%       0.000000   117.000000    14.000000     3.000000
# 75%       0.100000   313.000000    47.000000     5.000000
# max       0.850000  6517.000000  2476.000000    14.000000

# %%
dmart['State'].unique()
# Out:
# array(['Stockholm', 'England', 'Auvergne-Rhône-Alpes',
#        "Provence-Alpes-Côte d'Azur", 'Languedoc-Roussillon-Midi-Pyrénées',
#        'Liguria', 'Vienna', 'Murcia', 'Lower Saxony', 'South Holland',
#        'Västra Götaland', 'Hovedstaden', 'Valenciana', 'South Denmark',
#        'Lombardy', 'Sicily', 'Ile-de-France', 'North Rhine-Westphalia',
#        'Flemish Brabant', 'Tuscany', 'Emilia-Romagna', 'Madrid', 'Oslo',
#        'Lisboa', 'Saxony', 'Andalusía', 'Catalonia',
#        'Alsace-Champagne-Ardenne-Lorraine', 'Bavaria', 'Uppsala',
#        'Nord-Pas-de-Calais-Picardie', 'Hesse', 'Overijssel',
#        'Basel-Stadt', 'Bourgogne-Franche-Comté', 'Zürich', 'Dublin',
#        'Lazio', 'Namur', 'North Holland', 'Berlin', 'Baden-Württemberg',
#        'Aquitaine-Limousin-Poitou-Charentes', 'Uusimaa', 'Apulia',
#        'Saxony-Anhalt', 'Rogaland', 'Sardinia', 'Drenthe',
#        'Mecklenburg-Vorpommern', 'North Brabant', 'Umbria', 'Geneva',
# ...

# %%
dmart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8047 entries, 0 to 8046
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       8047 non-null   object
#  1   Order Date     8047 non-null   datetime64[ns]
#  2   Customer Name  8047 non-null   object
#  3   Country        8047 non-null   object
#  4   State          8047 non-null   object
#  5   City           8047 non-null   object
#  6   Region         8047 non-null   object
#  7   Segment        8047 non-null   object
#  8   Ship Mode      8047 non-null   object
#  9   Category       8047 non-null   object
#  10  Sub-Category   8047 non-null   object
#  11  Product Name   8047 non-null   object
#  12  Discount       8047 non-null   float64
#  13  Sales          8047 non-null   int64
#  14  Profit         8047 non-null   int64
#  15  Quantity       8047 non-null   int64
#  16  Feedback?      8047 non-null   bool
# ...

# %%
dmart['Order Date'].unique()
# Out:
# array(['2011-01-01T00:00:00.000000000', '2011-01-03T00:00:00.000000000',
#        '2011-01-04T00:00:00.000000000', ...,
#        '2014-12-29T00:00:00.000000000', '2014-12-30T00:00:00.000000000',
#        '2014-12-31T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
dmart['State'].value_counts()
# Out:
# England                       1187
# Ile-de-France                  673
# North Rhine-Westphalia         572
# Provence-Alpes-Côte d'Azur     250
# Madrid                         199
#                               ...
# Södermanland                     1
# Zeeland                          1
# Aveiro                           1
# Extremadura                      1
# Setúbal                          1
# Name: State, Length: 127, dtype: int64

# %%
dmart.iloc[2,3]
# Out:
# 'France'

# %%
dmart['Sales'].mean()
# Out:
# 291.84565676649686

# %%
dmart['Profit'].mean()
# Out:
# 35.19821051323475

# %%
dmart['Ship Mode'].mode()
# Out:
# 0    Economy
# Name: Ship Mode, dtype: object

# %%
dmart['Sales'].hist()
# Out:
# <Axes: >

# %%
dmart['Profit'].hist()
# Out:
# <Axes: >

# %%
dmart.groupby('Category').mean()
# Out:
# C:\Users\Chaitra\AppData\Local\Temp\ipykernel_18544\332863839.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dmart.groupby('Category').mean()
#                  Discount       Sales     Profit  Quantity  Feedback?
# Category
# Furniture        0.155008  516.000808  40.172859  3.748788   0.491115
# Office Supplies  0.094968  155.818767  23.638290  3.765040   0.496595
# Technology       0.125837  581.756402  71.276428  3.815496   0.512804

# %%
dmart.shape
# Out:
# (8047, 17)

# %%
dmart1=dmart.iloc[:,[13]]

# %%
dmart.std()
# Out:
# C:\Users\Chaitra\AppData\Local\Temp\ipykernel_18544\695602072.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dmart.std()
# Order Date    413 days 13:25:54.999291744
# Discount                         0.181773
# Sales                          485.212156
# Profit                         178.125844
# Quantity                         2.203369
# Feedback?                         0.50003
# dtype: object

# %%
dmart['Sales'].max()
# Out:
# 6517

# %%
dmart['Sales'].min()
# Out:
# 3

# %%
dmart['Sales']=dmart['Sales'].replace(6517,291.84)

# %%
dmart['Sales'].max()
# Out:
# 5785.0

# %%
dmart.std()
# Out:
# C:\Users\Chaitra\AppData\Local\Temp\ipykernel_18544\695602072.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dmart.std()
# Order Date    413 days 13:25:54.999291744
# Discount                         0.181773
# Sales                          480.222723
# Profit                         178.125844
# Quantity                         2.203369
# Feedback?                         0.50003
# dtype: object

# %%
dmart['Sales']
# Out:
# 0        45.0
# 1       854.0
# 2       140.0
# 3        27.0
# 4        17.0
#         ...
# 8042    245.0
# 8043     30.0
# 8044     23.0
# 8045    108.0
# 8046    867.0
# Name: Sales, Length: 8047, dtype: float64

# %%
dmart1.corr()
# Out:
#        Sales
# Sales    1.0

# %%
dmart.value_counts()
# Out:
# Order ID         Order Date  Customer Name      Country         State            City      Region   Segment      Ship Mode     Category         Sub-Category  Product Name                                    Discount  Sales  Profit  Quantity  Feedback?
# AZ-2012-5907386  2012-08-29  Louie Knight       Belgium         Antwerp          Mechelen  Central  Consumer     Economy       Office Supplies  Art           Sanford Pens, Fluorescent                       0.0       37.0    10     3         False        2
# AZ-2013-5637964  2013-06-14  Cynthia Zielinski  Spain           Madrid           Madrid    South    Home Office  Economy       Office Supplies  Binders       Wilson Jones 3-Hole Punch, Economy              0.0       84.0    28     3         True         2
# ...

# %%
dmart['Segment'].value_counts()
# Out:
# Consumer       4174
# Corporate      2514
# Home Office    1359
# Name: Segment, dtype: int64

# %%
dmart=dmart.replace('?',np.nan)

# %%
dmart.isnull().sum()
# Out:
# Order ID         0
# Order Date       0
# Customer Name    0
# Country          0
# State            0
# City             0
# Region           0
# Segment          0
# Ship Mode        0
# Category         0
# Sub-Category     0
# Product Name     0
# Discount         0
# Sales            0
# Profit           0
# Quantity         0
# Feedback?        0
# dtype: int64

# %%
dmart.head()
# Out:
#           Order ID Order Date     Customer Name         Country  \
# 0  BN-2011-7407039 2011-01-01        Ruby Patel          Sweden
# 1  AZ-2011-9050313 2011-01-03    Summer Hayward  United Kingdom
# 2  AZ-2011-6674300 2011-01-04  Devin Huddleston          France
# 3  BN-2011-2819714 2011-01-04       Mary Parker  United Kingdom
# 4  BN-2011-2819714 2011-01-04       Mary Parker  United Kingdom
#
#                   State        City   Region      Segment     Ship Mode  \
# 0             Stockholm   Stockholm    North  Home Office  Economy Plus
# 1               England   Southport    North     Consumer       Economy
# 2  Auvergne-Rhône-Alpes     Valence  Central     Consumer       Economy
# 3               England  Birmingham    North    Corporate       Economy
# 4               England  Birmingham    North    Corporate       Economy
#
#           Category Sub-Category                           Product Name  \
# 0  Office Supplies        Paper            Enermax Note Cards, Premium
# ...

# %%
dmart.dropna(axis=0)
# Out:
#              Order ID Order Date     Customer Name         Country  \
# 0     BN-2011-7407039 2011-01-01        Ruby Patel          Sweden
# 1     AZ-2011-9050313 2011-01-03    Summer Hayward  United Kingdom
# 2     AZ-2011-6674300 2011-01-04  Devin Huddleston          France
# 3     BN-2011-2819714 2011-01-04       Mary Parker  United Kingdom
# 4     BN-2011-2819714 2011-01-04       Mary Parker  United Kingdom
# ...               ...        ...               ...             ...
# 8042   AZ-2014-766953 2014-12-31      Jose Gambino  United Kingdom
# 8043  BN-2014-4140795 2014-12-31   Daniel Hamilton     Netherlands
# 8044  BN-2014-4140795 2014-12-31   Daniel Hamilton     Netherlands
# 8045  BN-2014-4140795 2014-12-31   Daniel Hamilton     Netherlands
# 8046   AZ-2014-766953 2014-12-31      Jose Gambino  United Kingdom
#
#                      State        City   Region      Segment     Ship Mode  \
# 0                Stockholm   Stockholm    North  Home Office  Economy Plus
# ...

# %%
dmart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8047 entries, 0 to 8046
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       8047 non-null   object
#  1   Order Date     8047 non-null   datetime64[ns]
#  2   Customer Name  8047 non-null   object
#  3   Country        8047 non-null   object
#  4   State          8047 non-null   object
#  5   City           8047 non-null   object
#  6   Region         8047 non-null   object
#  7   Segment        8047 non-null   object
#  8   Ship Mode      8047 non-null   object
#  9   Category       8047 non-null   object
#  10  Sub-Category   8047 non-null   object
#  11  Product Name   8047 non-null   object
#  12  Discount       8047 non-null   float64
#  13  Sales          8047 non-null   float64
#  14  Profit         8047 non-null   int64
#  15  Quantity       8047 non-null   int64
#  16  Feedback?      8047 non-null   bool
# ...

# %%
dmart
# Out:
#              Order ID Order Date     Customer Name         Country  \
# 0     BN-2011-7407039 2011-01-01        Ruby Patel          Sweden
# 1     AZ-2011-9050313 2011-01-03    Summer Hayward  United Kingdom
# 2     AZ-2011-6674300 2011-01-04  Devin Huddleston          France
# 3     BN-2011-2819714 2011-01-04       Mary Parker  United Kingdom
# 4     BN-2011-2819714 2011-01-04       Mary Parker  United Kingdom
# ...               ...        ...               ...             ...
# 8042   AZ-2014-766953 2014-12-31      Jose Gambino  United Kingdom
# 8043  BN-2014-4140795 2014-12-31   Daniel Hamilton     Netherlands
# 8044  BN-2014-4140795 2014-12-31   Daniel Hamilton     Netherlands
# 8045  BN-2014-4140795 2014-12-31   Daniel Hamilton     Netherlands
# 8046   AZ-2014-766953 2014-12-31      Jose Gambino  United Kingdom
#
#                      State        City   Region      Segment     Ship Mode  \
# 0                Stockholm   Stockholm    North  Home Office  Economy Plus
# ...

# %%
dmart.fillna(dmart.mean())
# Out:
# C:\Users\Chaitra\AppData\Local\Temp\ipykernel_18544\2220935328.py:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   dmart.fillna(dmart.mean())
# C:\Users\Chaitra\AppData\Local\Temp\ipykernel_18544\2220935328.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dmart.fillna(dmart.mean())
#              Order ID Order Date     Customer Name         Country  \
# 0     BN-2011-7407039 2011-01-01        Ruby Patel          Sweden
# 1     AZ-2011-9050313 2011-01-03    Summer Hayward  United Kingdom
# 2     AZ-2011-6674300 2011-01-04  Devin Huddleston          France
# 3     BN-2011-2819714 2011-01-04       Mary Parker  United Kingdom
# ...

# %%
dmart.drop_duplicates()
# Out:
#              Order ID Order Date     Customer Name         Country  \
# 0     BN-2011-7407039 2011-01-01        Ruby Patel          Sweden
# 1     AZ-2011-9050313 2011-01-03    Summer Hayward  United Kingdom
# 2     AZ-2011-6674300 2011-01-04  Devin Huddleston          France
# 3     BN-2011-2819714 2011-01-04       Mary Parker  United Kingdom
# 4     BN-2011-2819714 2011-01-04       Mary Parker  United Kingdom
# ...               ...        ...               ...             ...
# 8042   AZ-2014-766953 2014-12-31      Jose Gambino  United Kingdom
# 8043  BN-2014-4140795 2014-12-31   Daniel Hamilton     Netherlands
# 8044  BN-2014-4140795 2014-12-31   Daniel Hamilton     Netherlands
# 8045  BN-2014-4140795 2014-12-31   Daniel Hamilton     Netherlands
# 8046   AZ-2014-766953 2014-12-31      Jose Gambino  United Kingdom
#
#                      State        City   Region      Segment     Ship Mode  \
# 0                Stockholm   Stockholm    North  Home Office  Economy Plus
# ...

# %%
dmart['Ship Mode'].hist()
# Out:
# <Axes: >

# %%
dmart.groupby('Ship Mode').mean()
# Out:
# C:\Users\Chaitra\AppData\Local\Temp\ipykernel_18544\154432036.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dmart.groupby('Ship Mode').mean()
#               Discount       Sales     Profit  Quantity  Feedback?
# Ship Mode
# Economy       0.109214  290.575278  36.753599  3.782394   0.499177
# Economy Plus  0.111289  300.465308  34.173585  3.773585   0.500000
# Immediate     0.090258  308.248826  41.241784  3.659624   0.483568
# Priority      0.119033  274.102652  27.920445  3.768178   0.501283

# %%
dmart=dmart.drop(columns='Feedback?')

# %%
dmart
# Out:
#              Order ID Order Date     Customer Name         Country  \
# 0     BN-2011-7407039 2011-01-01        Ruby Patel          Sweden
# 1     AZ-2011-9050313 2011-01-03    Summer Hayward  United Kingdom
# 2     AZ-2011-6674300 2011-01-04  Devin Huddleston          France
# 3     BN-2011-2819714 2011-01-04       Mary Parker  United Kingdom
# 4     BN-2011-2819714 2011-01-04       Mary Parker  United Kingdom
# ...               ...        ...               ...             ...
# 8042   AZ-2014-766953 2014-12-31      Jose Gambino  United Kingdom
# 8043  BN-2014-4140795 2014-12-31   Daniel Hamilton     Netherlands
# 8044  BN-2014-4140795 2014-12-31   Daniel Hamilton     Netherlands
# 8045  BN-2014-4140795 2014-12-31   Daniel Hamilton     Netherlands
# 8046   AZ-2014-766953 2014-12-31      Jose Gambino  United Kingdom
#
#                      State        City   Region      Segment     Ship Mode  \
# 0                Stockholm   Stockholm    North  Home Office  Economy Plus
# ...

# %%
dmart['Customer Name'].str.strip("123./")
# Out:
# 0             Ruby Patel
# 1         Summer Hayward
# 2       Devin Huddleston
# 3            Mary Parker
# 4            Mary Parker
#               ...
# 8042        Jose Gambino
# 8043     Daniel Hamilton
# 8044     Daniel Hamilton
# 8045     Daniel Hamilton
# 8046        Jose Gambino
# Name: Customer Name, Length: 8047, dtype: object

# %%
dmart
# Out:
#              Order ID Order Date     Customer Name         Country  \
# 0     BN-2011-7407039 2011-01-01        Ruby Patel          Sweden
# 1     AZ-2011-9050313 2011-01-03    Summer Hayward  United Kingdom
# 2     AZ-2011-6674300 2011-01-04  Devin Huddleston          France
# 3     BN-2011-2819714 2011-01-04       Mary Parker  United Kingdom
# 4     BN-2011-2819714 2011-01-04       Mary Parker  United Kingdom
# ...               ...        ...               ...             ...
# 8042   AZ-2014-766953 2014-12-31      Jose Gambino  United Kingdom
# 8043  BN-2014-4140795 2014-12-31   Daniel Hamilton     Netherlands
# 8044  BN-2014-4140795 2014-12-31   Daniel Hamilton     Netherlands
# 8045  BN-2014-4140795 2014-12-31   Daniel Hamilton     Netherlands
# 8046   AZ-2014-766953 2014-12-31      Jose Gambino  United Kingdom
#
#                      State        City   Region      Segment     Ship Mode  \
# 0                Stockholm   Stockholm    North  Home Office  Economy Plus
# ...

# %%
import pandas as pd

# Assuming dmart is a DataFrame
dmart['State'] = dmart['State'].str.replace('[^a-zA-Z0-9]', '', regex=True)

# %%
dmart['State']
# Out:
# 0               Stockholm
# 1                 England
# 2       AuvergneRhneAlpes
# 3                 England
# 4                 England
#               ...
# 8042              England
# 8043         NorthBrabant
# 8044         NorthBrabant
# 8045         NorthBrabant
# 8046              England
# Name: State, Length: 8047, dtype: object

# %%
dmart['Product Name']=dmart['Product Name'].replace('[^a-zA-Z0-9]','',regex=True)

# %%
dmart['Product Name']
# Out:
# 0                EnermaxNoteCardsPremium
# 1         DaniaCornerShelvingTraditional
# 2          BinneySmithSketchPadEasyErase
# 3                 BostonMarkersEasyErase
# 4                EldonFoldersSingleWidth
#                       ...
# 8042    IkeaStackableBookrackTraditional
# 8043       BICPencilSharpenerFluorescent
# 8044           AveryBinderCoversRecycled
# 8045                    StarTechPhoneRed
# 8046               MotorolaAudioDockVoIP
# Name: Product Name, Length: 8047, dtype: object

# %%
dmart
# Out:
#              Order ID Order Date     Customer Name         Country  \
# 0     BN-2011-7407039 2011-01-01        Ruby Patel          Sweden
# 1     AZ-2011-9050313 2011-01-03    Summer Hayward  United Kingdom
# 2     AZ-2011-6674300 2011-01-04  Devin Huddleston          France
# 3     BN-2011-2819714 2011-01-04       Mary Parker  United Kingdom
# 4     BN-2011-2819714 2011-01-04       Mary Parker  United Kingdom
# ...               ...        ...               ...             ...
# 8042   AZ-2014-766953 2014-12-31      Jose Gambino  United Kingdom
# 8043  BN-2014-4140795 2014-12-31   Daniel Hamilton     Netherlands
# 8044  BN-2014-4140795 2014-12-31   Daniel Hamilton     Netherlands
# 8045  BN-2014-4140795 2014-12-31   Daniel Hamilton     Netherlands
# 8046   AZ-2014-766953 2014-12-31      Jose Gambino  United Kingdom
#
#                   State        City   Region      Segment     Ship Mode  \
# 0             Stockholm   Stockholm    North  Home Office  Economy Plus
# ...

# %%
max_length = 50
dmart['Product Name'] = dmart['Product Name'].str[:max_length]

# %%
dmart
# Out:
#              Order ID Order Date     Customer Name         Country  \
# 0     BN-2011-7407039 2011-01-01        Ruby Patel          Sweden
# 1     AZ-2011-9050313 2011-01-03    Summer Hayward  United Kingdom
# 2     AZ-2011-6674300 2011-01-04  Devin Huddleston          France
# 3     BN-2011-2819714 2011-01-04       Mary Parker  United Kingdom
# 4     BN-2011-2819714 2011-01-04       Mary Parker  United Kingdom
# ...               ...        ...               ...             ...
# 8042   AZ-2014-766953 2014-12-31      Jose Gambino  United Kingdom
# 8043  BN-2014-4140795 2014-12-31   Daniel Hamilton     Netherlands
# 8044  BN-2014-4140795 2014-12-31   Daniel Hamilton     Netherlands
# 8045  BN-2014-4140795 2014-12-31   Daniel Hamilton     Netherlands
# 8046   AZ-2014-766953 2014-12-31      Jose Gambino  United Kingdom
#
#                   State        City   Region      Segment     Ship Mode  \
# 0             Stockholm   Stockholm    North  Home Office  Economy Plus
# ...

# %%
dmart.tail(10)
# Out:
#              Order ID Order Date        Customer Name         Country  \
# 8037   AZ-2014-436448 2014-12-30     Georgia Arundale           Italy
# 8038  AZ-2014-1412225 2014-12-31          Leon Barnes  United Kingdom
# 8039  AZ-2014-4217323 2014-12-31          Evie Morton          France
# 8040  AZ-2014-8174835 2014-12-31         Eloise Sykes         Germany
# 8041  AZ-2014-7604524 2014-12-31  Rebecca Chamberlain         Germany
# 8042   AZ-2014-766953 2014-12-31         Jose Gambino  United Kingdom
# 8043  BN-2014-4140795 2014-12-31      Daniel Hamilton     Netherlands
# 8044  BN-2014-4140795 2014-12-31      Daniel Hamilton     Netherlands
# 8045  BN-2014-4140795 2014-12-31      Daniel Hamilton     Netherlands
# 8046   AZ-2014-766953 2014-12-31         Jose Gambino  United Kingdom
#
#                      State        City   Region      Segment     Ship Mode  \
# 8037              Campania      Naples    South    Corporate       Economy
# ...

# %%
dmart.head(10)
# Out:
#           Order ID Order Date       Customer Name         Country  \
# 0  BN-2011-7407039 2011-01-01          Ruby Patel          Sweden
# 1  AZ-2011-9050313 2011-01-03      Summer Hayward  United Kingdom
# 2  AZ-2011-6674300 2011-01-04    Devin Huddleston          France
# 3  BN-2011-2819714 2011-01-04         Mary Parker  United Kingdom
# 4  BN-2011-2819714 2011-01-04         Mary Parker  United Kingdom
# 5   AZ-2011-617423 2011-01-05        Daniel Burke          France
# 6   AZ-2011-617423 2011-01-05        Daniel Burke          France
# 7  AZ-2011-2918397 2011-01-07  Fredrick Beveridge          France
# 8  AZ-2011-2918397 2011-01-07  Fredrick Beveridge          France
# 9  AZ-2011-2918397 2011-01-07  Fredrick Beveridge          France
#
#                    State              City   Region      Segment  \
# 0              Stockholm         Stockholm    North  Home Office
# 1                England         Southport    North     Consumer
# ...

# %%
dmart['City']=dmart['City'].replace('[^a-zA-Z0-9]','',regex=True)

# %%
dmart['City']
# Out:
# 0        Stockholm
# 1        Southport
# 2          Valence
# 3       Birmingham
# 4       Birmingham
#            ...
# 8042    Maidenhead
# 8043     Eindhoven
# 8044     Eindhoven
# 8045     Eindhoven
# 8046    Maidenhead
# Name: City, Length: 8047, dtype: object

# %%
dmart.head(10)
# Out:
#           Order ID Order Date       Customer Name         Country  \
# 0  BN-2011-7407039 2011-01-01          Ruby Patel          Sweden
# 1  AZ-2011-9050313 2011-01-03      Summer Hayward  United Kingdom
# 2  AZ-2011-6674300 2011-01-04    Devin Huddleston          France
# 3  BN-2011-2819714 2011-01-04         Mary Parker  United Kingdom
# 4  BN-2011-2819714 2011-01-04         Mary Parker  United Kingdom
# 5   AZ-2011-617423 2011-01-05        Daniel Burke          France
# 6   AZ-2011-617423 2011-01-05        Daniel Burke          France
# 7  AZ-2011-2918397 2011-01-07  Fredrick Beveridge          France
# 8  AZ-2011-2918397 2011-01-07  Fredrick Beveridge          France
# 9  AZ-2011-2918397 2011-01-07  Fredrick Beveridge          France
#
#                    State           City   Region      Segment     Ship Mode  \
# 0              Stockholm      Stockholm    North  Home Office  Economy Plus
# 1                England      Southport    North     Consumer       Economy
# ...

# %%
dmart['Order ID']=dmart['Order ID'].replace('[^0-9]','',regex=True)

# %%
dmart['Order ID']
# Out:
# 0       20117407039
# 1       20119050313
# 2       20116674300
# 3       20112819714
# 4       20112819714
#            ...
# 8042     2014766953
# 8043    20144140795
# 8044    20144140795
# 8045    20144140795
# 8046     2014766953
# Name: Order ID, Length: 8047, dtype: object

# %%
dmart
# Out:
#          Order ID Order Date     Customer Name         Country  \
# 0     20117407039 2011-01-01        Ruby Patel          Sweden
# 1     20119050313 2011-01-03    Summer Hayward  United Kingdom
# 2     20116674300 2011-01-04  Devin Huddleston          France
# 3     20112819714 2011-01-04       Mary Parker  United Kingdom
# 4     20112819714 2011-01-04       Mary Parker  United Kingdom
# ...           ...        ...               ...             ...
# 8042   2014766953 2014-12-31      Jose Gambino  United Kingdom
# 8043  20144140795 2014-12-31   Daniel Hamilton     Netherlands
# 8044  20144140795 2014-12-31   Daniel Hamilton     Netherlands
# 8045  20144140795 2014-12-31   Daniel Hamilton     Netherlands
# 8046   2014766953 2014-12-31      Jose Gambino  United Kingdom
#
#                   State        City   Region      Segment     Ship Mode  \
# 0             Stockholm   Stockholm    North  Home Office  Economy Plus
# ...

# %%
dmart['Product Name'].str.split(',',2,expand=True)
# Out:
# C:\Users\Chaitra\AppData\Local\Temp\ipykernel_18544\3793506721.py:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   dmart['Product Name'].str.split(',',2,expand=True)
#                                      0
# 0              EnermaxNoteCardsPremium
# 1       DaniaCornerShelvingTraditional
# 2        BinneySmithSketchPadEasyErase
# 3               BostonMarkersEasyErase
# 4              EldonFoldersSingleWidth
# ...                                ...
# 8042  IkeaStackableBookrackTraditional
# 8043     BICPencilSharpenerFluorescent
# 8044         AveryBinderCoversRecycled
# 8045                  StarTechPhoneRed
# 8046             MotorolaAudioDockVoIP
#
# [8047 rows x 1 columns]

# %%
import re

# Assuming 'Product Name' is the name of the column containing the data
dmart['Product Name'] = dmart['Product Name'].str.replace(r'([a-z])([A-Z])', r'\1 \2')
# Out:
# C:\Users\Chaitra\AppData\Local\Temp\ipykernel_18544\4180411826.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   dmart['Product Name'] = dmart['Product Name'].str.replace(r'([a-z])([A-Z])', r'\1 \2')

# %%
dmart['Product Name']
# Out:
# 0                Enermax Note Cards Premium
# 1         Dania Corner Shelving Traditional
# 2        Binney Smith Sketch Pad Easy Erase
# 3                 Boston Markers Easy Erase
# 4                Eldon Folders Single Width
#                        ...
# 8042    Ikea Stackable Bookrack Traditional
# 8043        BICPencil Sharpener Fluorescent
# 8044           Avery Binder Covers Recycled
# 8045                    Star Tech Phone Red
# 8046              Motorola Audio Dock Vo IP
# Name: Product Name, Length: 8047, dtype: object

# %%
dmart
# Out:
#          Order ID Order Date     Customer Name         Country  \
# 0     20117407039 2011-01-01        Ruby Patel          Sweden
# 1     20119050313 2011-01-03    Summer Hayward  United Kingdom
# 2     20116674300 2011-01-04  Devin Huddleston          France
# 3     20112819714 2011-01-04       Mary Parker  United Kingdom
# 4     20112819714 2011-01-04       Mary Parker  United Kingdom
# ...           ...        ...               ...             ...
# 8042   2014766953 2014-12-31      Jose Gambino  United Kingdom
# 8043  20144140795 2014-12-31   Daniel Hamilton     Netherlands
# 8044  20144140795 2014-12-31   Daniel Hamilton     Netherlands
# 8045  20144140795 2014-12-31   Daniel Hamilton     Netherlands
# 8046   2014766953 2014-12-31      Jose Gambino  United Kingdom
#
#                   State        City   Region      Segment     Ship Mode  \
# 0             Stockholm   Stockholm    North  Home Office  Economy Plus
# ...

# %%
dmart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8047 entries, 0 to 8046
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       8047 non-null   object
#  1   Order Date     8047 non-null   datetime64[ns]
#  2   Customer Name  8047 non-null   object
#  3   Country        8047 non-null   object
#  4   State          8047 non-null   object
#  5   City           8047 non-null   object
#  6   Region         8047 non-null   object
#  7   Segment        8047 non-null   object
#  8   Ship Mode      8047 non-null   object
#  9   Category       8047 non-null   object
#  10  Sub-Category   8047 non-null   object
#  11  Product Name   8047 non-null   object
#  12  Discount       8047 non-null   float64
#  13  Sales          8047 non-null   float64
#  14  Profit         8047 non-null   int64
#  15  Quantity       8047 non-null   int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(11)
# ...

# %%
dmart = pd.DataFrame(dmart)

# %%
dmart
# Out:
#          Order ID Order Date     Customer Name         Country  \
# 0     20117407039 2011-01-01        Ruby Patel          Sweden
# 1     20119050313 2011-01-03    Summer Hayward  United Kingdom
# 2     20116674300 2011-01-04  Devin Huddleston          France
# 3     20112819714 2011-01-04       Mary Parker  United Kingdom
# 4     20112819714 2011-01-04       Mary Parker  United Kingdom
# ...           ...        ...               ...             ...
# 8042   2014766953 2014-12-31      Jose Gambino  United Kingdom
# 8043  20144140795 2014-12-31   Daniel Hamilton     Netherlands
# 8044  20144140795 2014-12-31   Daniel Hamilton     Netherlands
# 8045  20144140795 2014-12-31   Daniel Hamilton     Netherlands
# 8046   2014766953 2014-12-31      Jose Gambino  United Kingdom
#
#                   State        City   Region      Segment     Ship Mode  \
# 0             Stockholm   Stockholm    North  Home Office  Economy Plus
# ...

# %%
dmart = pd.read_csv("dmart.csv")

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Chaitra

# %%
os.chdir('/path/to/your/directory')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[143], line 1
# ----> 1 os.chdir('/path/to/your/directory')
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '/path/to/your/directory'

# %%
os.chdir(r'C:\Users\YourUsername\Desktop\data')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[146], line 1
# ----> 1 os.chdir(r'C:\Users\YourUsername\Desktop\data')
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\Users\\YourUsername\\Desktop\\data'

# %%
os.chdir(r'C:\path\to\your\actual\directory')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[147], line 1
# ----> 1 os.chdir(r'C:\path\to\your\actual\directory')
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\path\\to\\your\\actual\\directory'

# %%
# Import the Pandas library (if not already imported)
import pandas as pd

# Assuming you have a DataFrame named 'df'
# Use the to_csv method to save the DataFrame to a CSV file
dmart.to_csv('dmart.csv', index=False)

# %%
import pandas as pd

# Sample data in the format '2011-01-01'
dmart = pd.DataFrame(dmart)

# Convert the 'date' column to a datetime object
dmart['date'] = pd.to_datetime(dmart['date'])

# Extract the year and create a new column
dmart['year'] = dmart['date'].dt.year

# Display the updated DataFrame
print(dmart)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\OneDrive\anaconda1\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\OneDrive\anaconda1\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\OneDrive\anaconda1\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# ...
